# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'> DIABETES</font></h1></div><br>
#
# <div style = 'border : 3px solid brown;background-color:lightyellow;padding :10px'>
# Diabetes is a chronic medical condition that affects how your body processes glucose, a type of sugar that serves as the primary source of energy. When we consume food, especially carbohydrates, our digestive system breaks down the food into glucose, which enters the bloodstream. In response, the pancreas releases a hormone called insulin, which helps transport glucose from the bloodstream into the body's cells, where it can be utilized for energy.
#
# In people with diabetes, there is a disruption in the production or utilization of insulin, leading to elevated blood sugar levels. This happens due to one of the following reasons:
#
# > **Type 1 Diabetes**: This form of diabetes is an autoimmune condition where the immune system mistakenly attacks and destroys the insulin-producing cells in the pancreas. As a result, the body produces little to no insulin. Type 1 diabetes typically develops in childhood or early adulthood and requires lifelong insulin therapy.
#
# > **Type 2 Diabetes** This is the most common form of diabetes, accounting for the majority of cases. In type 2 diabetes, the body becomes resistant to the effects of insulin, and the pancreas may not produce enough insulin to compensate for this resistance. It often occurs in individuals who are overweight, physically inactive, or have a family history of diabetes. Type 2 diabetes can be managed through lifestyle modifications, such as a healthy diet, regular exercise, oral medications, and, in some cases, insulin injections.
#
# > **Gestational Diabetes** This type of diabetes affects pregnant women who have high blood sugar levels during pregnancy. It usually resolves after giving birth, but women who have had gestational diabetes are at a higher risk of developing type 2 diabetes later in life.
#
# It's important to note that the information provided here is a general overview, and the management of diabetes should be personalized based on individual circumstances. If you or someone you know has diabetes, it is recommended to consult with a healthcare professional for proper diagnosis, treatment, and guidance.
# </div>

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'> DESCRIPTION ABOUT DIABETIES :</font></h1></div><br>
# <div style = 'border : 3px solid brown; background-color : lightyellow;padding : 10px'>
# Diabetes is a chronic medical condition that affects how your body processes glucose, a type of sugar that serves as the primary source of energy. When we consume food, especially carbohydrates, our digestive system breaks down the food into glucose, which enters the bloodstream. In response, the pancreas releases a hormone called insulin, which helps transport glucose from the bloodstream into the body's cells, where it can be utilized for energy.
#
# In people with diabetes, there is a disruption in the production or utilization of insulin, leading to elevated blood sugar levels. This happens due to one of the following reasons:
#
# 1. **Type 1 Diabetes**: This form of diabetes is an autoimmune condition where the immune system mistakenly attacks and destroys the insulin-producing cells in the pancreas. As a result, the body produces little to no insulin. Type 1 diabetes typically develops in childhood or early adulthood and requires lifelong insulin therapy.
#
# 2. **Type 2 Diabetes**: This is the most common form of diabetes, accounting for the majority of cases. In type 2 diabetes, the body becomes resistant to the effects of insulin, and the pancreas may not produce enough insulin to compensate for this resistance. It often occurs in individuals who are overweight, physically inactive, or have a family history of diabetes. Type 2 diabetes can be managed through lifestyle modifications, such as a healthy diet, regular exercise, oral medications, and, in some cases, insulin injections.
#
# 3. **Gestational Diabetes**: This type of diabetes affects pregnant women who have high blood sugar levels during pregnancy. It usually resolves after giving birth, but women who have had gestational diabetes are at a higher risk of developing type 2 diabetes later in life.
#
# Uncontrolled diabetes can lead to various complications affecting different parts of the body, including the heart, blood vessels, eyes, kidneys, and nerves. Common complications include cardiovascular diseases, diabetic retinopathy (vision problems), diabetic neuropathy (nerve damage), kidney disease, and poor wound healing.
#
# Managing diabetes involves maintaining blood sugar levels within a target range through a combination of healthy eating, regular physical activity, monitoring blood sugar levels, taking medications (including insulin, if necessary), and regular check-ups with healthcare professionals. Lifestyle modifications are crucial in managing type 2 diabetes, and medication or insulin may be prescribed if blood sugar levels remain uncontrolled.
#
# It's important to note that the information provided here is a general overview, and the management of diabetes should be personalized based on individual circumstances. If you or someone you know has diabetes, it is recommended to consult with a healthcare professional for proper diagnosis, treatment, and guidance.
#
# ### AIM :
#
# The aim of a diabetes dataset is to provide information and insights about diabetes and its management. It helps researchers understand the disease, identify patterns and risk factors, develop predictive models, and improve diabetes care. The dataset is used to study the effectiveness of treatments, predict diabetes progression, support clinical decision-making, and plan public health strategies.
# </div>

# %% [markdown]
# <div style = 'border : 3px solid brown; background-color:lightyellow;padding:10px'><h3>Details about the dataset:</h3>
#
# + Pregnancies decribes the number of times the person has been pregnant.
# + Gluose describes the blood glucose level on testing.
# + Blood pressure describes the diastolic blood pressure.
# + Skin Thickenss describes the skin fold thickness of the triceps.
# + Insulin describes the amount of insulin in a 2hour serum test.
# + BMI describes he body mass index.
# + DiabetesPedigreeFunction describes the family history of the person.
# + Age describes the age of the person
# + Outcome describes if the person is predicted to have diabetes or not.
#
# + It should also be noted that the dataset has no missing values and thus, filling up the dataset using algorithms will not be necessary.
# </div>

# %%
# import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings #avoid warning flash
warnings.filterwarnings('ignore')

# %%
dataframe = pd.read_csv("diabetes.csv")
dataframe.head(10).style.set_properties(
    **{
        'background-color': 'OliveDrab',
        'color': 'white',
        'border-color': 'darkblack'
    })
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'>Exploratory Data Analysis(EDA)</font></h1></div>

# %%
print('Shape of Diabetes dataset is :',dataframe.shape)
print('Size of Diabetes dataset is  :',dataframe.size)
# Out:
# Shape of Diabetes dataset is : (768, 9)
# Size of Diabetes dataset is  : 6912

# %%
print(f'This Diabetes dataset has {dataframe.shape[0]} instances with the {dataframe.shape[1]-1} features and 1 output variable')
# Out:
# This Diabetes dataset has 768 instances with the 8 features and 1 output variable

# %%
dataframe.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Drop if there are duplicates rows.
dataframe = dataframe.drop_duplicates()

# %%
dataframe.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
plt.rcParams.update({'font.size': 20})

dataframe.dtypes.value_counts().plot.pie(explode=[0.1, 0.1],
                                       autopct='%1.2f%%',
                                       shadow=True)
plt.title('Data Type',
          color='Green',
          loc='center',
          font='Times New Roman');

# %% [markdown]
# <div style ='border:3px solid brown;background-color:lightyellow;padding:3px'><h3> ABOUT GRAPH :</h3>
#
# >From the above pie chart we can see that the "int type" data is more compare to "float type".
#
# >The generated graph is a pie chart that represents the distribution of data types in a dataframe. Each slice of the pie represents a unique data type, and the size of each slice corresponds to the percentage of occurrence of that data type in the dataframe.
# </div>

# %%
dataframe.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Some of the features has 0 as the minimum value in the dataset such as
# Glucose, Blood Pressure, SkinThickness, Insulin and Bmi we can replace it with
# mean, median or mode

# %%
plt.figure(figsize=(20,16))
corrmat=dataframe.corr()
sns.heatmap(corrmat, annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# <div style = 'border:3px solid brown; background-color:lightyellow;padding:10px'>Pearson's Correlation Coefficient : Helps you find out the relationship between two quantities. It gives you the measure of the strength of association between two variables. The value of Pearson's Correlation Coefficient can be between <b> -1 to +1. 1</b> means that they are highly correlated and 0 means no correlation.
#
# A heat map is a two-dimensional representation of information with the help of colors. Heat maps can help the user visualize simple or complex information
# </div>

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'>
#
# > Observe the last row 'Outcome' and note its correlation scores with different features. We can observe that Glucose, BMI and Age are the most correlated with Outcome. BloodPressure, Insulin, DiabetesPedigreeFunction are the least correlated.
#
# </div>

# %%
# show how many columns has 0 values and sum it

featureList = ['Glucose', 'BloodPressure','SkinThickness','Insulin','BMI']
print(dataframe[featureList].isin({0}).sum())
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h4><font color = 'black'>Replacing 0 values with mean or median of that column</font></h4></div>

# %%
dataframe['Glucose']=dataframe['Glucose'].replace(0,dataframe['Glucose'].mean())#normal distribution
dataframe['BloodPressure']=dataframe['BloodPressure'].replace(0,dataframe['BloodPressure'].mean())#normal distribution
dataframe['SkinThickness']=dataframe['SkinThickness'].replace(0,dataframe['SkinThickness'].median())#skewed distribution
dataframe['Insulin']=dataframe['Insulin'].replace(0,dataframe['Insulin'].median())#skewed distribution
dataframe['BMI']=dataframe['BMI'].replace(0,dataframe['BMI'].median())#skewed distribution

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h4><font color = 'black'> Now verify whether there are any 0 values </font></h4></div>

# %%
featureList = ['Glucose', 'BloodPressure','SkinThickness','Insulin','BMI']
print(dataframe[featureList].isin({0}).sum())
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# check for Null values 
import missingno as msno
msno.bar(dataframe)
plt.show()

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h3>ABOUT GRAPH</h3>
#
# + From the above graph we can see all the features in a dataset having same number of null values.So it will be easy further
# </div>

# %%
# replacing the value 0 and 1 in column name Outcome for readability
dataframe["Outcome"].replace(0,"Non-Diabetic",inplace=True) 
dataframe["Outcome"].replace(1,"Diabetic",inplace=True)
dataframe["Outcome"]
# Out:
# 0          Diabetic
# 1      Non-Diabetic
# 2          Diabetic
# 3      Non-Diabetic
# 4          Diabetic
#            ...
# 763    Non-Diabetic
# 764    Non-Diabetic
# 765    Non-Diabetic
# 766        Diabetic
# 767    Non-Diabetic
# Name: Outcome, Length: 768, dtype: object

# %%
# plot the no of patients 
plt.figure(figsize=(14,6))

ax = plt.subplot(1,2,1)
ax = sns.countplot(x='Outcome', data=dataframe)
ax.bar_label(ax.containers[0])
plt.title("Outcome", fontsize=20)

ax =plt.subplot(1,2,2)
ax=dataframe['Outcome'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Outcome", fontsize = 20,color='Red',font='Lucida Calligraphy');

# %% [markdown]
# <div style = 'border: 3px solid brown;background-color:lightyellow;padding:10px'><h4> ABOUT GRAPHS :</h4>
#
# + There are more non-diabetic patients than the diabetic patients.
#
# >From the above subplots,you will obtain a figure with two subplots. The left subplot is a countplot that represents the distribution of outcomes in the dataset using bars, with the count values displayed on top of each bar. The right subplot is a pie chart that visually represents the distribution of outcomes using slices, with the percentage values displayed on each slice. Both subplots have titles indicating the purpose of the charts.
#
# </div>

# %%
# for my analysis purpose i am saving the diabetic and non-diabetic data in different variables.
Diabetic = dataframe[dataframe["Outcome"]=="Diabetic"]
Non_diabetic = dataframe[dataframe["Outcome"]=="Non-Diabetic"]

# %%
Diabetic.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6    148.0           72.0             35     30.5  33.6  \
# 2            8    183.0           64.0             23     30.5  23.3
# 4            0    137.0           40.0             35    168.0  43.1
# 6            3     78.0           50.0             32     88.0  31.0
# 8            2    197.0           70.0             45    543.0  30.5
#
#    DiabetesPedigreeFunction  Age   Outcome
# 0                     0.627   50  Diabetic
# 2                     0.672   32  Diabetic
# 4                     2.288   33  Diabetic
# 6                     0.248   26  Diabetic
# 8                     0.158   53  Diabetic

# %%
Diabetic.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   268.000000  268.000000     268.000000     268.000000  268.000000  \
# mean      4.865672  142.159661      74.950326      29.716418  116.041045
# std       3.741239   29.545943      12.016572       9.676886  127.689084
# min       0.000000   78.000000      30.000000       7.000000   14.000000
# 25%       1.750000  119.000000      68.000000      23.000000   30.500000
# 50%       4.000000  140.000000      74.000000      27.000000   30.500000
# 75%       8.000000  167.000000      82.000000      36.000000  167.250000
# max      17.000000  199.000000     114.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  268.000000                268.000000  268.000000
# mean    35.381343                  0.550500   37.067164
# std      6.596704                  0.372354   10.968254
# min     22.900000                  0.088000   21.000000
# ...

# %%
Non_diabetic.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness   Insulin
# count   500.000000  500.000000     500.000000     500.000000  500.0000  \
# mean      3.298000  110.705367      70.810008      26.058000   83.1880
# std       3.017185   24.715021      11.932269       8.725532   89.5657
# min       0.000000   44.000000      24.000000       7.000000   15.0000
# 25%       1.000000   93.000000      63.500000      22.000000   30.5000
# 50%       2.000000  107.500000      70.000000      23.000000   39.0000
# 75%       5.000000  125.000000      78.000000      31.000000  105.0000
# max      13.000000  197.000000     122.000000      60.000000  744.0000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  500.000000                500.000000  500.000000
# mean    30.880200                  0.429734   31.190000
# std      6.503074                  0.299085   11.667655
# min     18.200000                  0.078000   21.000000
# ...

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h3><font color = 'black'> Analysing the glucose levels in the dataset</font></h3></div>

# %%
x1=len(dataframe[dataframe["Glucose"]<=140])
x2=len(dataframe[(dataframe["Glucose"]>140)&(dataframe["Glucose"]<=199)])
x3=len(dataframe[dataframe["Glucose"]>=200])
print("patient count having normal Blood sugar :",x1)
print("patient count having prediabetes :",x2)
print("patient count having abnormal glucose :",x3)
# dataframe[dataframe['Outcome'] == 1]
# Out:
# patient count having normal Blood sugar : 576
# patient count having prediabetes : 192
# patient count having abnormal glucose : 0

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4> RESULTS :</h4>
#
# Based on the results, the chart and count values provide information about the distribution of patients based on their blood sugar levels or outcomes. Here's what we can infer from the results:
#
# >+ **Patient count having normal blood sugar**: The count is 576. This means that 576 patients in the dataset have been categorized as having normal blood sugar levels.
#
# >+ **Patient count having prediabetes**: The count is 192. This means that 192 patients in the dataset have been categorized as having prediabetes, which indicates that their blood sugar levels are higher than normal but not high enough to be classified as diabetes.
#
# >+ **Patient count having abnormal glucose**: The count is 0. This suggests that there are no patients in the dataset categorized as having abnormal glucose levels. This could mean that the dataset doesn't include any cases with significantly high blood sugar levels.
#
# Overall, these results provide insights into the blood sugar levels of the patients in the dataset, with the majority having normal blood sugar and a smaller proportion having prediabetes.
# </div>

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'>
#
# >192 has diabetes by analysing with the glucose but we have total 268 in the datafram but what is the reason?
# we will try by analysing the features insulin, bmi, skin thickness, diabetespedigreefunction
#
# </div>

# %%
sns.displot(dataframe, x='BMI', hue='Outcome', kind='kde')

# %% [markdown]
# <div style = 'border :3px solid brown;background-color:lightyellow;padding:10px'><h4> ABOUT GRAPH :</h4>
#
# + The resulting density plot will show a smooth curve that represents the estimated density of 'BMI' values in the dataset. By incorporating the 'Outcome' variable, it allows for a visual comparison of the density distributions for different outcome groups. This can help identify any differences or similarities in the distribution of 'BMI' values based on different outcomes.
#
# + Overall, the density plot provides a visual summary of the distribution and density of 'BMI' values, giving insights into how the data is distributed and any potential patterns or differences based on the 'Outcome' variable.
#
# </div>

# %%
### saving the patient details whose Glucose level is normal and are diabetic in a dataframe.
a=dataframe[(dataframe["Glucose"]<=140)&(dataframe["Outcome"]=="Diabetic")]
a
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 4              0    137.0      40.000000             35    168.0  43.1  \
# 6              3     78.0      50.000000             32     88.0  31.0
# 9              8    125.0      96.000000             23     30.5  32.0
# 15             7    100.0      69.105469             23     30.5  30.0
# 16             0    118.0      84.000000             47    230.0  45.8
# ..           ...      ...            ...            ...      ...   ...
# 743            9    140.0      94.000000             23     30.5  32.7
# 750            4    136.0      70.000000             23     30.5  31.2
# 755            1    128.0      88.000000             39    110.0  36.5
# 757            0    123.0      72.000000             23     30.5  36.3
# 766            1    126.0      60.000000             23     30.5  30.1
#
#      DiabetesPedigreeFunction  Age   Outcome
# 4                       2.288   33  Diabetic
# ...

# %% [markdown]
# sugar blood glucose level is <140 still some has diagnosed with diabetes by having more BMI, Insulin, Age

# %%
import seaborn as sns
sns.catplot(x="Outcome",y="Glucose",data=a)

# %%
sns.catplot(x="Outcome",y="BloodPressure",data=a, kind="swarm")

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4>Insight:</h4>
#
# The relation between Blood pressure and Diabetic people is not showing any considerable information so we can not say blood pressure could be the factor
#
# <h4> BMI Range:</h4>
#
# >below 18.5 – you're in the underweight range
#
# >between 18.5 and 24.9 – you're in the healthy weight range
#
# >between 25 and 29.9 – you're in the overweight range
#
# >between 30 and 39.9 – you're in the obese range
# </div>

# %%
sns.catplot(x="Outcome",y="BMI",data=a, kind="swarm")

# %%
z=dataframe[(dataframe["Age"]>=35) & (dataframe["BMI"]>=30)& (dataframe["Outcome"]=="Diabetic")]
z[z["Pregnancies"]==0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 66             0    109.0           88.0             30     30.5  32.5  \
# 440            0    189.0          104.0             25     30.5  34.3
# 506            0    180.0           90.0             26     90.0  36.5
# 757            0    123.0           72.0             23     30.5  36.3
#
#      DiabetesPedigreeFunction  Age   Outcome
# 66                      0.855   38  Diabetic
# 440                     0.435   41  Diabetic
# 506                     0.314   35  Diabetic
# 757                     0.258   52  Diabetic

# %% [markdown]
# 4 females of age >35 can be considered as infertile females as they didnt get pregnant as they are obese,diabetic and age is not so young

# %%
plt.figure(figsize=(24,16))
sns.relplot(x='Glucose',y="Insulin",data=dataframe,hue="Outcome")

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4> ABOUT GRAPH :</h4>
#
# + Glucose value(beyond 130) is increasing as insulin value increases in diabetic patients.
# A scatter plot is used to visualize the relationship between two continuous variables. Each point on the plot represents a data point and its position on the x-axis and y-axis represents the values of the corresponding variables.
#
# + The resulting scatter plot will display the relationship between **'Glucose' and 'Insulin'** values for each data point in the dataset. By incorporating the 'Outcome' variable as the hue, it provides insights into how the 'Glucose' and 'Insulin' values vary across different outcome groups. It can help identify any patterns, trends, or correlations between these two variables and their association with the outcome categories.
# </div>

# %%
# Age vs BMI
sns.relplot(x='Age',y="BMI",data=dataframe,hue="Outcome")

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4>ABOUT GRAPH :</h4>
#
# Diabetic patients are obese and adults (greater than 30).
# The resulting scatter plot will show the relationship between 'Age' and 'BMI' values for each data point in the dataset. By incorporating the 'Outcome' variable as the hue, it provides insights into how the 'Age' and 'BMI' values vary across different outcome groups. It can help identify any patterns, trends, or correlations between these two variables and their association with the outcome categories.
# </div>

# %%
# BMI VS SKINTHICKNESS
sns.relplot(x='BMI',y="SkinThickness",data=dataframe,hue="Outcome")

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4>ABOUT GRAPH :</h4>
#
# Obese have more skin thickness.The resulting scatter plot will show the relationship between 'BMI' and 'SkinThickness' values for each data point in the dataset. By incorporating the 'Outcome' variable as the hue, it provides insights into how the 'BMI' and 'SkinThickness' values vary across different outcome groups. It can help identify any patterns, trends, or correlations between these two variables and their association with the outcome categories.
# </div>

# %%
dataframe.hist(figsize = (20,20))
# Out:
# array([[<AxesSubplot: title={'center': 'Pregnancies'}>,
#         <AxesSubplot: title={'center': 'Glucose'}>,
#         <AxesSubplot: title={'center': 'BloodPressure'}>],
#        [<AxesSubplot: title={'center': 'SkinThickness'}>,
#         <AxesSubplot: title={'center': 'Insulin'}>,
#         <AxesSubplot: title={'center': 'BMI'}>],
#        [<AxesSubplot: title={'center': 'DiabetesPedigreeFunction'}>,
#         <AxesSubplot: title={'center': 'Age'}>, <AxesSubplot: >]],
#       dtype=object)

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4> Conclusion :-</h4>
#
# **We observe that only glucose and Blood Pressure are normally distributed rest others are skewed and have outliers**
#
# The given code generates a 3x3 array of subplots using the `subplots` function from Matplotlib. Each subplot represents a different variable/column from the dataset. Let's break down the subplots and explain each one:
#
# - Subplot 1: `Pregnancies`
#     - This subplot represents the distribution of the 'Pregnancies' variable/column.
#     - The title of the subplot is "Pregnancies".
#
# - Subplot 2: `Glucose`
#     - This subplot represents the distribution of the 'Glucose' variable/column.
#     - The title of the subplot is "Glucose".
#
# - Subplot 3: `BloodPressure`
#     - This subplot represents the distribution of the 'BloodPressure' variable/column.
#     - The title of the subplot is "BloodPressure".
#
# - Subplot 4: `SkinThickness`
#     - This subplot represents the distribution of the 'SkinThickness' variable/column.
#     - The title of the subplot is "SkinThickness".
#
# - Subplot 5: `Insulin`
#     - This subplot represents the distribution of the 'Insulin' variable/column.
#     - The title of the subplot is "Insulin".
#
# - Subplot 6: `BMI`
#     - This subplot represents the distribution of the 'BMI' variable/column.
#     - The title of the subplot is "BMI".
#
# - Subplot 7: `DiabetesPedigreeFunction`
#     - This subplot represents the distribution of the 'DiabetesPedigreeFunction' variable/column.
#     - The title of the subplot is "DiabetesPedigreeFunction".
#
# - Subplot 8: `Age`
#     - This subplot represents the distribution of the 'Age' variable/column.
#     - The title of the subplot is "Age".
#
# >Overall, the code generates a grid of 3 rows and 3 columns, with each subplot representing the distribution of a specific variable from the dataset. It provides a visual representation of the distributions and allows for quick comparisons between the variables. The titles of each subplot indicate the variable being plotted in that particular subplot.
#
# </div>

# %%
# Using for loop to visualize the boxplot to detect outliers
x = dataframe.drop(['Outcome'],axis = 1) # drop dependent feature and plot the outliers.
for i in x.columns:
    sns.boxplot(x = i, data = x,color = 'blue')
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4>ABOUT OUTLIERS :</h4>
#
# >Outliers are unusual values in your dataset, and they can distort statistical analyses and violate their assumptions. Hence it is of utmost importance to deal with them. In this case removing outliers can cause data loss so we have to deal with it using various scaling and transformation techniques.
# </div>

# %%
sns.pairplot(dataframe,vars=['Pregnancies','BloodPressure','SkinThickness','BMI','Glucose','Insulin','Age'],hue='Outcome',palette='plasma',aspect=1.9)

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4>Pairplot</h4>
#
# >Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our dataset.

# %%
dataframe = dataframe.replace({'Outcome': {'Non-Diabetic': 0, 'Diabetic': 1}})
dataframe.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6    148.0           72.0             35     30.5  33.6  \
# 1            1     85.0           66.0             29     30.5  26.6
# 2            8    183.0           64.0             23     30.5  23.3
# 3            1     89.0           66.0             23     94.0  28.1
# 4            0    137.0           40.0             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Feature Selection
df_selected=dataframe.copy(deep=True)

# %%
# Handling Outliers

# %%
# Quantile Transformer 
from sklearn.preprocessing import QuantileTransformer
x=df_selected
quantile  = QuantileTransformer()
X = quantile.fit_transform(x)
df_new=quantile.transform(X)
df_new=pd.DataFrame(X)
df_new.columns =['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction','Age', 'Outcome']
df_new.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI
# 0     0.747718  0.810300       0.516949       0.801825  0.256193  0.591265  \
# 1     0.232725  0.091265       0.290091       0.644720  0.256193  0.213168
# 2     0.863755  0.956975       0.233377       0.357888  0.256193  0.077575
# 3     0.232725  0.124511       0.290091       0.357888  0.662973  0.284224
# 4     0.000000  0.721643       0.005215       0.801825  0.834420  0.926988
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.750978  0.889831      1.0
# 1                  0.475880  0.558670      0.0
# 2                  0.782269  0.585398      1.0
# 3                  0.106258  0.000000      0.0
# 4                  0.997392  0.606258      1.0

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4> ABOUT THE DISTRIBUTIONS :</h4>
#
# >Numerical input variables may have a highly skewed or non-standard distribution.
# This could be caused by outliers in the data, multi-model distributions, highly exponential distributions, and more.
# </div>

# %%
# verify if the outliers are present or not.
x = df_new.drop(['Outcome'],axis = 1)
for i in x.columns:
    sns.boxplot(x = i, data = x,color = 'blue') 
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h1> Split the data </h1>
#
# #### Why do we split the data?
#
# Splitting the data into training and testing sets is a common practice in machine learning and data analysis. The purpose of splitting the data is to evaluate the performance and generalization ability of a model.
#
# Here are the key reasons for splitting the data:
#
# >**Model Evaluation:** By splitting the data into training and testing sets, we can assess how well our model performs on unseen data. The training set is used to train the model, while the testing set is used to evaluate its performance. This evaluation helps us understand how well the model generalizes to new, unseen data.
#
# >**Avoiding Overfitting:** Overfitting occurs when a model becomes too closely tailored to the training data and performs poorly on new data. Splitting the data allows us to detect and prevent overfitting. By evaluating the model's performance on the testing set, we can determine if the model is overfitting or if it can generalize well to unseen data.
#
#
# In summary, splitting the data into training and testing sets allows us to evaluate the model's performance on unseen data, prevent overfitting, optimize hyperparameters, and obtain unbiased performance estimates. It is a crucial step in the machine learning workflow to ensure the model's reliability and generalization capabilities.
# </div>

# %%
X = df_new.drop(columns='Outcome', axis=1)
Y = df_new['Outcome']

# %%
X.head() # independent features
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI
# 0     0.747718  0.810300       0.516949       0.801825  0.256193  0.591265  \
# 1     0.232725  0.091265       0.290091       0.644720  0.256193  0.213168
# 2     0.863755  0.956975       0.233377       0.357888  0.256193  0.077575
# 3     0.232725  0.124511       0.290091       0.357888  0.662973  0.284224
# 4     0.000000  0.721643       0.005215       0.801825  0.834420  0.926988
#
#    DiabetesPedigreeFunction       Age
# 0                  0.750978  0.889831
# 1                  0.475880  0.558670
# 2                  0.782269  0.585398
# 3                  0.106258  0.000000
# 4                  0.997392  0.606258

# %%
Y.tail()  # Dependent features
# Out:
# 763    0.0
# 764    0.0
# 765    0.0
# 766    1.0
# 767    0.0
# Name: Outcome, dtype: float64

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'> Train And Test Split</font></h1></div>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,Y,test_size=0.3,random_state=12) # Splitting in the ratio of 60% for train, 40% for test.

# %%
X_train.shape, y_train.shape
# Out:
# ((537, 8), (537,))

# %%
X_test.shape, y_test.shape
# Out:
# ((231, 8), (231,))

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'>
# <h1>Model Implementation</h1>
#
# <h3>LOGISTIC REGRESSION</h3>
#
# <h4>Why do we use Logistic Regression?</h4>
#
# While logistic regression has its limitations, such as assuming linearity and limited representation of complex relationships, it remains a widely used and effective algorithm in various applications, including the analysis of the diabetes dataset. Its ability to handle binary classification tasks, interpretability, efficiency, and suitability as a baseline model make it a popular choice in the context of the diabetes dataset.
#
# Certainly! Logistic regression is a statistical modeling technique used for binary classification tasks. It is specifically designed for situations where the dependent variable (or outcome) is categorical with two possible classes, such as "yes/no," "true/false," or in the case of the diabetes dataset, "diabetic/non-diabetic."
#
# In logistic regression, the goal is to estimate the probability of an observation belonging to a specific class based on one or more independent variables (also known as features or predictors). The output of logistic regression is a probability value between 0 and 1, which can be interpreted as the likelihood of belonging to the positive class (e.g., being diabetic).
#
# The logistic regression model uses a logistic function (also called a sigmoid function) to transform a linear combination of the input features into the predicted probability. This transformation ensures that the predicted probabilities fall within the valid range of 0 to 1. The logistic function is defined as:
#
# >**P(y = 1|X) = 1 / (1 + e^-(b0 + b1x1 + b2x2 + ... + bnxn))**
#
# where:
#
# >- P(y = 1|X) is the probability of the positive class given the input features X.
# >- e is the base of the natural logarithm (approximately 2.718).
# >- b0, b1, b2, ..., bn are the coefficients of the logistic regression model that determine the impact of each feature on the outcome.
# >- x1, x2, ..., xn are the corresponding feature values for a given observation.
#
# </div>

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'> Logistic Regression</font></h1></div>

# %%
pip install --upgrade scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001C35B431590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/scikit-learn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001C35B431F50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/scikit-learn/
# ...

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression
logic = LogisticRegression()
logic.fit(X_train, y_train)
y_pred_lr = logic.predict(X_test)

log_train = round(logic.score(X_train, y_train) * 100, 2)
log_accuracy = round(accuracy_score(y_pred_lr, y_test) * 100, 2)

print("Training Accuracy    :",log_train ,"%")
print("Model Accuracy Score :",log_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_lr))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 75.98 %
# Model Accuracy Score : 77.92 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.86      0.83       147
#          1.0       0.73      0.63      0.68        84
#
#     accuracy                           0.78       231
#    macro avg       0.76      0.75      0.75       231
# weighted avg       0.78      0.78      0.78       231
#
# --------------------------------------------------------

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4> Results:</h4>
# The results you provided are as follows:
#
# 1. **Training Accuracy**: The training accuracy of the logistic regression model is 75.98%. This means that the model correctly predicts the outcome for approximately 75.98% of the instances in the training dataset.
#
# 2. **Model Accuracy Score**: The accuracy score of the logistic regression model on the test data is 77.92%. This indicates that the model correctly predicts the outcome for approximately 77.92% of the instances in the test dataset.
#
# 3. **Classification Report**: The classification report provides evaluation metrics such as precision, recall, and F1-score for each class (0.0 and 1.0) in the test data. Here's an explanation of the metrics:
#
#    - **Precision**: Precision measures the proportion of correctly predicted positive instances out of all instances predicted as positive. For class 0.0, the precision is 0.80, indicating that 80% of the instances predicted as non-diabetic are actually non-diabetic. For class 1.0, the precision is 0.73, indicating that 73% of the instances predicted as diabetic are actually diabetic.
#
#    - **Recall**: Recall (also known as sensitivity or true positive rate) measures the proportion of correctly predicted positive instances out of all actual positive instances. For class 0.0, the recall is 0.86, meaning that 86% of the actual non-diabetic instances are correctly identified as non-diabetic. For class 1.0, the recall is 0.63, meaning that 63% of the actual diabetic instances are correctly identified as diabetic.
#
#    - **F1-score**: The F1-score is the harmonic mean of precision and recall. It provides a balanced measure of the model's performance by considering both precision and recall. For class 0.0, the F1-score is 0.83, and for class 1.0, the F1-score is 0.68.
#
#    - **Support**: The support represents the number of instances belonging to each class in the test data. There are 147 instances of class 0.0 (non-diabetic) and 84 instances of class 1.0 (diabetic).
#
# 4. **Accuracy, Macro Avg, Weighted Avg**: The accuracy is the overall accuracy of the model on the test data, which is 78%. The macro average calculates the average of precision, recall, and F1-score across all classes, giving equal weight to each class. The weighted average considers the number of instances for each class, providing a weighted average based on class distribution.
#
# Based on these results, the logistic regression model demonstrates a reasonable level of performance in predicting diabetes on the given dataset. It achieves accuracy rates above 75% on both the training and test data, indicating that it can make reasonably accurate predictions. However, the model's performance may vary for different classes, with slightly higher precision, recall, and F1-scores for the non-diabetic class compared to the diabetic class.
#
# </div>

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h1> Support Vector Machines</h1>
#
# ##### why do we use SVMs ?
#
# While SVMs have advantages in handling nonlinear data, outliers, and high-dimensional spaces, it's important to note that they may have limitations as well. SVMs can be computationally intensive and may require careful parameter tuning. Additionally, SVMs may not perform optimally when the dataset is imbalanced or when there is a large overlap between classes.
#
# SVMs are a popular choice for the diabetes dataset due to their ability to handle nonlinear data, robustness to outliers, effectiveness in high-dimensional spaces, generalization performance, and binary classification capability.
# </div>

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
y_pred_svc = svc.predict(X_test)

svc_train = round(svc.score(X_train, y_train) * 100, 2)
svc_accuracy = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_svc))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 81.56 %
# Model Accuracy Score : 77.06 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.86      0.83       147
#          1.0       0.71      0.62      0.66        84
#
#     accuracy                           0.77       231
#    macro avg       0.75      0.74      0.74       231
# weighted avg       0.77      0.77      0.77       231
#
# --------------------------------------------------------

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4>Results:</h4>
#
# The results you provided for the SVM model on the diabetes dataset are as follows:
#
# >1. **Training Accuracy**: The SVM model achieved a training accuracy of 100%. This means that the model correctly predicted the outcomes of all instances in the training dataset. A training accuracy of 100% suggests that the model has memorized the training data and may be overfitting.
#
# >2. **Model Accuracy Score**: The accuracy score of the SVM model on the test data is 69.7%. This indicates that the model correctly predicted the outcomes of approximately 69.7% of the instances in the test dataset. The model's accuracy on the test data is lower than the training accuracy, which could indicate overfitting or limitations in generalizing to unseen data.
#
# >3. **Classification Report**: The classification report provides evaluation metrics such as precision, recall, and F1-score for each class (0.0 and 1.0) in the test data. Here's an explanation of the metrics:
#
#    - **Precision**: Precision measures the proportion of correctly predicted positive instances out of all instances predicted as positive. For class 0.0, the precision is 0.78, indicating that 78% of the instances predicted as non-diabetic are actually non-diabetic. For class 1.0, the precision is 0.57, indicating that 57% of the instances predicted as diabetic are actually diabetic.
#
#    - **Recall**: Recall (also known as sensitivity or true positive rate) measures the proportion of correctly predicted positive instances out of all actual positive instances. For class 0.0, the recall is 0.73, meaning that 73% of the actual non-diabetic instances are correctly identified as non-diabetic. For class 1.0, the recall is 0.64, meaning that 64% of the actual diabetic instances are correctly identified as diabetic.
#
#    - **F1-score**: The F1-score is the harmonic mean of precision and recall. It provides a balanced measure of the model's performance by considering both precision and recall. For class 0.0, the F1-score is 0.75, and for class 1.0, the F1-score is 0.61.
#
#    - **Support**: The support represents the number of instances belonging to each class in the test data. There are 147 instances of class 0.0 (non-diabetic) and 84 instances of class 1.0 (diabetic).
#
# >4. **Accuracy, Macro Avg, Weighted Avg**: The overall accuracy of the model on the test data is 70%. The macro average of precision, recall, and F1-score is 0.68, indicating a relatively balanced performance across the classes. The weighted average, which considers class distribution, is also 0.70.
#
# These results suggest that the SVM model may not generalize well to unseen data. Further investigation, such as parameter tuning or considering alternative models, may be necessary to improve the model's performance and address the overfitting issue.
# </div>

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'> Decission Tree Classifier</font></h1></div>

# %%
from sklearn.tree import DecisionTreeClassifier
decision = DecisionTreeClassifier()
decision.fit(X_train, y_train)
y_pred_dec = decision.predict(X_test)

decision_train = round(decision.score(X_train, y_train) * 100, 2)
decision_accuracy = round(accuracy_score(y_pred_dec, y_test) * 100, 2)

print("Training Accuracy    :",decision_train ,"%")
print("Model Accuracy Score :",decision_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_dec))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 67.97 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#          0.0       0.75      0.74      0.75       147
#          1.0       0.56      0.57      0.56        84
#
#     accuracy                           0.68       231
#    macro avg       0.65      0.66      0.66       231
# weighted avg       0.68      0.68      0.68       231
#
# --------------------------------------------------------

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4> Results :</h4>
#
# The results from the code snippet you provided for the SVM model on the diabetes dataset are as follows:
#
# >1. **Training Accuracy**: The SVM model achieved a training accuracy of 100%. This means that the model correctly predicted all instances in the training dataset. However, a training accuracy of 100% could indicate overfitting, where the model has memorized the training data and may not generalize well to unseen data.
#
# >2. **Model Accuracy Score**: The accuracy score of the SVM model on the test data is 69.7%. This indicates that the model correctly predicted approximately 69.7% of the instances in the test dataset. The lower accuracy score on the test data compared to the training accuracy suggests that the model may be overfitting and not performing as well on unseen data.
#
# >3. **Classification Report**: The classification report provides evaluation metrics such as precision, recall, and F1-score for each class (0.0 and 1.0) in the test data. Here's an explanation of the metrics:
#
#    - **Precision**: Precision measures the proportion of correctly predicted positive instances out of all instances predicted as positive. For class 0.0, the precision is 0.78, indicating that 78% of the instances predicted as non-diabetic are actually non-diabetic. For class 1.0, the precision is 0.57, indicating that 57% of the instances predicted as diabetic are actually diabetic.
#
#    - **Recall**: Recall (also known as sensitivity or true positive rate) measures the proportion of correctly predicted positive instances out of all actual positive instances. For class 0.0, the recall is 0.73, meaning that 73% of the actual non-diabetic instances are correctly identified as non-diabetic. For class 1.0, the recall is 0.64, meaning that 64% of the actual diabetic instances are correctly identified as diabetic.
#
#    - **F1-score**: The F1-score is the harmonic mean of precision and recall. It provides a balanced measure of the model's performance by considering both precision and recall. For class 0.0, the F1-score is 0.75, and for class 1.0, the F1-score is 0.61.
#
#    - **Support**: The support represents the number of instances belonging to each class in the test data. There are 147 instances of class 0.0 (non-diabetic) and 84 instances of class 1.0 (diabetic).
#
# >4. **Accuracy, Macro Avg, Weighted Avg**: The overall accuracy of the model on the test data is 70%. The macro average of precision, recall, and F1-score is 0.68, indicating a relatively balanced performance across the classes. The weighted average, which considers class distribution, is also 0.70.
#
# Based on these results, it seems that the SVM model may have overfit the training data, as it achieves perfect accuracy on the training set but lower accuracy on the test set. The model's performance on the test set is suboptimal, with an accuracy of 69.7% and relatively lower precision, recall, and F1-scores for both classes. Further investigation and model refinement may be required to improve the model's generalization performance and address the overfitting issue.
# </div>

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

knn_train = round(knn.score(X_train, y_train) * 100, 2)
knn_accuracy = round(accuracy_score(y_pred_knn, y_test) * 100, 2)

print("Training Accuracy    :",knn_train ,"%")
print("Model Accuracy Score :",knn_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_knn))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 85.85 %
# Model Accuracy Score : 73.16 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#          0.0       0.77      0.83      0.80       147
#          1.0       0.65      0.56      0.60        84
#
#     accuracy                           0.73       231
#    macro avg       0.71      0.69      0.70       231
# weighted avg       0.73      0.73      0.73       231
#
# --------------------------------------------------------

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px'><h4>Results :</h4>
#
#
# >1. **Training Accuracy**: The logistic regression model achieved a training accuracy of 85.85%. This means that the model correctly predicted 85.85% of the instances in the training dataset.
#
# >2. **Model Accuracy Score**: The accuracy score of the logistic regression model on the test data is 73.16%. This indicates that the model correctly predicted approximately 73.16% of the instances in the test dataset.
#
# >3. **Classification Report**: The classification report provides evaluation metrics such as precision, recall, and F1-score for each class (0.0 and 1.0) in the test data. Here's an explanation of the metrics:
#
#    - **Precision**: Precision measures the proportion of correctly predicted positive instances out of all instances predicted as positive. For class 0.0, the precision is 0.77, indicating that 77% of the instances predicted as non-diabetic are actually non-diabetic. For class 1.0, the precision is 0.65, indicating that 65% of the instances predicted as diabetic are actually diabetic.
#
#    - **Recall**: Recall (also known as sensitivity or true positive rate) measures the proportion of correctly predicted positive instances out of all actual positive instances. For class 0.0, the recall is 0.83, meaning that 83% of the actual non-diabetic instances are correctly identified as non-diabetic. For class 1.0, the recall is 0.56, meaning that 56% of the actual diabetic instances are correctly identified as diabetic.
#
#    - **F1-score**: The F1-score is the harmonic mean of precision and recall. It provides a balanced measure of the model's performance by considering both precision and recall. For class 0.0, the F1-score is 0.80, and for class 1.0, the F1-score is 0.60.
#
#    - **Support**: The support represents the number of instances belonging to each class in the test data. There are 147 instances of class 0.0 (non-diabetic) and 84 instances of class 1.0 (diabetic).
#
# >4. **Accuracy, Macro Avg, Weighted Avg**: The overall accuracy of the model on the test data is 73.16%. The macro average of precision, recall, and F1-score is 0.70, indicating a relatively balanced performance across the classes. The weighted average, which considers class distribution, is also 0.73.
#
# Based on these updated results, the logistic regression model shows improved performance compared to the previous results. It achieves a reasonably high accuracy of 73.16% on the test data, along with respectable precision, recall, and F1-scores for both classes. However, there is still room for further improvement, particularly in the recall and F1-score for the diabetic class (1.0). Additional analysis and model refinement may be necessary to enhance the model's predictive capabilities on the diabetes dataset.

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'> Comparing Different Models</font></h1></div>

# %%
# Create a variable 
models = pd.DataFrame({'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression','Decission Tree'],
                       'Training Accuracy':[svc_train,knn_train,log_train,decision_train],
                       'Model Accuracy':[svc_accuracy,knn_accuracy,log_accuracy,decision_accuracy]})

# %%
models.sort_values(by='Model Accuracy', ascending=False).style.background_gradient(
        cmap='coolwarm')
        # .hide_index().set_properties(**{
        #     'font-family': 'Lucida Calligraphy',
        #     'color': 'LigntGreen',
        #     'font-size': '15px'
        # })
# Out:
# <style type="text/css">
# #T_0cab1_row0_col1, #T_0cab1_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0cab1_row0_col2, #T_0cab1_row3_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0cab1_row1_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_0cab1_row1_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_0cab1_row2_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_0cab1_row2_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# </style>
# <table id="T_0cab1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cab1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0cab1_level0_col1" class="col_heading level0 col1" >Training Accuracy</th>
#       <th id="T_0cab1_level0_col2" class="col_heading level0 col2" >Model Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
colors = ["purple", "green", "orange", "magenta","blue","black"]

sns.set_style("whitegrid")
plt.figure(figsize=(16,8))
plt.ylabel("Accuracy %")
plt.xlabel("Algorithms")
sns.barplot(x=models['Model'],y=models['Model Accuracy'], palette=colors )
plt.show()

# %% [markdown]
# #### Conclusion:
#
# From the above plot we have seen that by comparing all the models the accuracy rate is good in Logistic Regression Model.

# %% [markdown]
# <div class = 'alert alert-block alert-warning'><h1><font color = 'black'> FINAL PREDICTIONS </font></h1></div>

# %%
# Make predictions on unseen data, here i have given random values for each features in the input_data
# take the data  and store in the variable 
input_data = (2,95,90,40,150,24,0.727000,20)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data) # converting this list into numpy array

# reshape the numpy array as we are predicting for one instance

input_data_reshaped= input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped)
# Out:
# [[  2.     95.     90.     40.    150.     24.      0.727  20.   ]]

# %%
# predict
predictions = logic.predict(input_data_reshaped)
print(predictions)
if predictions[0] == 1:
    print("The patient is predicted to have diabetes.")
else:
    print("The patient is predicted to not have diabetes.")
# Out:
# [1.]
# The patient is predicted to have diabetes.
